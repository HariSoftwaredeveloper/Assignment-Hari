# %%
import pandas as pd
from collections import Counter

# %% [markdown]
# **Path to the file**

# %%
log_file_path = "/kaggle/input/sample-log1/sample.log.csv"

# %% [markdown]
# **Read the log file and Display the DataFrame**

# %%
with open(log_file_path, "r") as file:
    logs = file.readlines()

parsed_data = []
for log in logs:
    parts = log.split()

    ip_address = parts[0]  
    timestamp = log.split("[")[1].split("]")[0] 
    request = " ".join(parts[5:8]).replace('"', '') 
    status_code = parts[8]  
    size = parts[9]  
    error_message = " ".join(parts[10:]).strip() if len(parts) > 10 else None  

    # Add the parsed data as a row
    parsed_data.append([ip_address, timestamp, request, status_code, size, error_message])


columns = ["IP Address", "Timestamp", "Request", "Status Code", "Size", "Error Message"]

df = pd.DataFrame(parsed_data, columns=columns)

output_file = "log_table.csv"
df.to_csv(output_file, index=False)

df.head()
# Out:
#       IP Address                   Timestamp                  Request  \
# 0    192.168.1.1  03/Dec/2024:10:12:34 +0000       GET /home HTTP/1.1
# 1    203.0.113.5  03/Dec/2024:10:12:35 +0000     POST /login HTTP/1.1
# 2       10.0.0.2  03/Dec/2024:10:12:36 +0000      GET /about HTTP/1.1
# 3    192.168.1.1  03/Dec/2024:10:12:37 +0000    GET /contact HTTP/1.1
# 4  198.51.100.23  03/Dec/2024:10:12:38 +0000  POST /register HTTP/1.1
#
#   Status Code Size          Error Message
# 0         200  512                   None
# 1         401  128  "Invalid credentials"
# 2         200  256                   None
# 3         200  312                   None
# 4         200  128                   None

# %% [markdown]
# Your Python script should implement the following functionalities:
#
# 1. **Count Requests per IP Address**:
#     - Parse the provided log file to extract all IP addresses.
#     - Calculate the number of requests made by each IP address.
#     - Sort and display the results in descending order of requestt counts.**

# %%
ip_request_counts = df["IP Address"].value_counts().reset_index()
ip_request_counts.columns = ["IP Address", "Request Count"]
ip_request_counts = ip_request_counts.sort_values(by="Request Count", ascending=False)
print(ip_request_counts)
# Out:
#       IP Address  Request Count
# 0    203.0.113.5              8
# 1  198.51.100.23              8
# 2    192.168.1.1              7
# 3       10.0.0.2              6
# 4  192.168.1.100              5

# %% [markdown]
# **2. **Identify the Most Frequently Accessed Endpoint**:
#     - Extract the endpoints (e.g., URLs or resource paths) from the log file.
#     - Identify the endpoint accessed the highest number of times.
#     - Provide the endpoint name and its access count.**

# %%
df['Endpoint'] = df['Request'].apply(lambda x: x.split()[1] if len(x.split()) > 1 else None)
endpoint_counts = df['Endpoint'].value_counts()
most_frequent_endpoint = endpoint_counts.idxmax()
count = endpoint_counts.max()
print(f"Most Frequently Accessed Endpoint:\n{most_frequent_endpoint} (Accessed {count} times)")
# Out:
# Most Frequently Accessed Endpoint:
# /login (Accessed 13 times)

# %%
threshold = 10
failed_logins = df[(df['Status Code'] == '401') | (df['Error Message'].str.contains("Invalid credentials", na=False))]
failed_login_counts = failed_logins['IP Address'].value_counts()

suspicious_activity = failed_login_counts[failed_login_counts > threshold]


if not suspicious_activity.empty:
    suspicious_df = pd.DataFrame({
        'IP Address': suspicious_activity.index,
        'Failed Login Attempts': suspicious_activity.values
    })
    print("Suspicious Activity Detected:")
    print(suspicious_df)
else:
    print("No suspicious activity detected.")
# Out:
# No suspicious activity detected.

# %% [markdown]
# **Since the threshold is set to 10 and the highest and lowest number of failed login attempts in the provided sample logs is 8 and 5, there are no IP addresses flagged for suspicious activity**

# %%
threshold = 2
failed_logins = df[(df['Status Code'] == '401') | (df['Error Message'].str.contains("Invalid credentials", na=False))]
failed_login_counts = failed_logins['IP Address'].value_counts()

suspicious_activity = failed_login_counts[failed_login_counts > threshold]


if not suspicious_activity.empty:
    suspicious_df = pd.DataFrame({
        'IP Address': suspicious_activity.index,
        'Failed Login Attempts': suspicious_activity.values
    })
    print("Suspicious Activity Detected:")
    print(suspicious_df)
else:
    print("No suspicious activity detected.")
# Out:
# Suspicious Activity Detected:
#       IP Address  Failed Login Attempts
# 0    203.0.113.5                      8
# 1  192.168.1.100                      5

# %% [markdown]
# **4. **Output Results**:
#     - Display the results in a clear, organized format in the terminal.
#     - Save the results to a CSV file named `log_analysis_results.csv` with the following structure:
#         - **Requests per IP**: Columns: `IP Address`, `Request Count`
#         - **Most Accessed Endpoint**: Columns: `Endpoint`, `Access Count`
#         - **Suspicious Activity**: Columns: `IP Address`, `Failed Login Count`**

# %%
import pandas as pd
ip_request_counts = df["IP Address"].value_counts().reset_index()
ip_request_counts.columns = ["IP Address", "Request Count"]
ip_request_counts = ip_request_counts.sort_values(by="Request Count", ascending=False)
print("\nRequests per IP Address:")
print(ip_request_counts)
ip_request_counts.to_csv('log_analysis_results.csv', index=False, mode='w', header=True)
df['Endpoint'] = df['Request'].apply(lambda x: x.split()[1] if len(x.split()) > 1 else None)
endpoint_counts = df['Endpoint'].value_counts()
most_frequent_endpoint = endpoint_counts.idxmax()
count = endpoint_counts.max()
print(f"\nMost Frequently Accessed Endpoint:\n{most_frequent_endpoint} (Accessed {count} times)")
endpoint_results = pd.DataFrame({
    'Endpoint': [most_frequent_endpoint],
    'Access Count': [count]
})

endpoint_results.to_csv('log_analysis_results.csv', index=False, mode='a', header=False)

threshold = 2
failed_logins = df[(df['Status Code'] == '401') | (df['Error Message'].str.contains("Invalid credentials", na=False))]
failed_login_counts = failed_logins['IP Address'].value_counts()
suspicious_activity = failed_login_counts[failed_login_counts > threshold]

if not suspicious_activity.empty:
    print("\nSuspicious Activity Detected:")
    suspicious_df = pd.DataFrame({
        'IP Address': suspicious_activity.index,
        'Failed Login Attempts': suspicious_activity.values
    })
    print(suspicious_df)
    suspicious_df.to_csv('log_analysis_results.csv', index=False, mode='a', header=False)
else:
    print("\nNo suspicious activity detected.")

print("\nAnalysis complete. Results saved to 'log_analysis_results.csv'.")
# Out:
# Requests per IP Address:
#       IP Address  Request Count
# 0    203.0.113.5              8
# 1  198.51.100.23              8
# 2    192.168.1.1              7
# 3       10.0.0.2              6
# 4  192.168.1.100              5
#
# Most Frequently Accessed Endpoint:
# /login (Accessed 13 times)
#
# Suspicious Activity Detected:
#       IP Address  Failed Login Attempts
# 0    203.0.113.5                      8
# 1  192.168.1.100                      5
#
# Analysis complete. Results saved to 'log_analysis_results.csv'.

# %%
df
# Out:
#        IP Address                   Timestamp                  Request  \
# 0     192.168.1.1  03/Dec/2024:10:12:34 +0000       GET /home HTTP/1.1
# 1     203.0.113.5  03/Dec/2024:10:12:35 +0000     POST /login HTTP/1.1
# 2        10.0.0.2  03/Dec/2024:10:12:36 +0000      GET /about HTTP/1.1
# 3     192.168.1.1  03/Dec/2024:10:12:37 +0000    GET /contact HTTP/1.1
# 4   198.51.100.23  03/Dec/2024:10:12:38 +0000  POST /register HTTP/1.1
# 5     203.0.113.5  03/Dec/2024:10:12:39 +0000     POST /login HTTP/1.1
# 6   192.168.1.100  03/Dec/2024:10:12:40 +0000     POST /login HTTP/1.1
# 7        10.0.0.2  03/Dec/2024:10:12:41 +0000  GET /dashboard HTTP/1.1
# 8   198.51.100.23  03/Dec/2024:10:12:42 +0000      GET /about HTTP/1.1
# 9     192.168.1.1  03/Dec/2024:10:12:43 +0000  GET /dashboard HTTP/1.1
# 10    203.0.113.5  03/Dec/2024:10:12:44 +0000     POST /login HTTP/1.1
# 11    203.0.113.5  03/Dec/2024:10:12:45 +0000     POST /login HTTP/1.1
# 12  192.168.1.100  03/Dec/2024:10:12:46 +0000     POST /login HTTP/1.1
# 13       10.0.0.2  03/Dec/2024:10:12:47 +0000    GET /profile HTTP/1.1
# 14    192.168.1.1  03/Dec/2024:10:12:48 +0000       GET /home HTTP/1.1
# 15  198.51.100.23  03/Dec/2024:10:12:49 +0000  POST /feedback HTTP/1.1
# 16    203.0.113.5  03/Dec/2024:10:12:50 +0000     POST /login HTTP/1.1
# 17    192.168.1.1  03/Dec/2024:10:12:51 +0000       GET /home HTTP/1.1
# 18  198.51.100.23  03/Dec/2024:10:12:52 +0000      GET /about HTTP/1.1
# 19    203.0.113.5  03/Dec/2024:10:12:53 +0000     POST /login HTTP/1.1
# 20  192.168.1.100  03/Dec/2024:10:12:54 +0000     POST /login HTTP/1.1
# 21       10.0.0.2  03/Dec/2024:10:12:55 +0000    GET /contact HTTP/1.1
# 22  198.51.100.23  03/Dec/2024:10:12:56 +0000       GET /home HTTP/1.1
# 23  192.168.1.100  03/Dec/2024:10:12:57 +0000     POST /login HTTP/1.1
# 24    203.0.113.5  03/Dec/2024:10:12:58 +0000     POST /login HTTP/1.1
# 25       10.0.0.2  03/Dec/2024:10:12:59 +0000  GET /dashboard HTTP/1.1
# 26    192.168.1.1  03/Dec/2024:10:13:00 +0000      GET /about HTTP/1.1
# 27  198.51.100.23  03/Dec/2024:10:13:01 +0000  POST /register HTTP/1.1
# 28    203.0.113.5  03/Dec/2024:10:13:02 +0000     POST /login HTTP/1.1
# 29  192.168.1.100  03/Dec/2024:10:13:03 +0000     POST /login HTTP/1.1
# 30       10.0.0.2  03/Dec/2024:10:13:04 +0000    GET /profile HTTP/1.1
# 31  198.51.100.23  03/Dec/2024:10:13:05 +0000      GET /about HTTP/1.1
# 32    192.168.1.1  03/Dec/2024:10:13:06 +0000       GET /home HTTP/1.1
# 33  198.51.100.23  03/Dec/2024:10:13:07 +0000  POST /feedback HTTP/1.1
#
#    Status Code  Size          Error Message    Endpoint
# 0          200   512                   None       /home
# 1          401   128  "Invalid credentials"      /login
# 2          200   256                   None      /about
# 3          200   312                   None    /contact
# 4          200   128                   None   /register
# 5          401   128  "Invalid credentials"      /login
# 6          401   128  "Invalid credentials"      /login
# 7          200  1024                   None  /dashboard
# 8          200   256                   None      /about
# 9          200  1024                   None  /dashboard
# 10         401   128  "Invalid credentials"      /login
# 11         401   128  "Invalid credentials"      /login
# 12         401   128  "Invalid credentials"      /login
# 13         200   768                   None    /profile
# 14         200   512                   None       /home
# 15         200   128                   None   /feedback
# 16         401   128  "Invalid credentials"      /login
# 17         200   512                   None       /home
# 18         200   256                   None      /about
# 19         401   128  "Invalid credentials"      /login
# 20         401   128  "Invalid credentials"      /login
# 21         200   512                   None    /contact
# 22         200   512                   None       /home
# 23         401   128  "Invalid credentials"      /login
# 24         401   128  "Invalid credentials"      /login
# 25         200  1024                   None  /dashboard
# 26         200   256                   None      /about
# 27         200   128                   None   /register
# 28         401   128  "Invalid credentials"      /login
# 29         401   128  "Invalid credentials"      /login
# 30         200   768                   None    /profile
# 31         200   256                   None      /about
# 32         200   512                   None       /home
# 33         200   128                   None   /feedback
